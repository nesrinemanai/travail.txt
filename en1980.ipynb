# %% [markdown]
# <a href="https://colab.research.google.com/github/nesrinemanai/travail.txt/blob/main/en1980.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Produit 1 : iPhone
id1 = 1
produit1 = "Iphone"
PrixUV1 = 2500      # Prix Unitaire de Vente
PrixUA1 = 2300      # Prix Unitaire d'Achat
promis1 = 10
quantite1 = 10

# Produit 2 : Samsung
id2 = 2
produit2 = "Samsung"
PrixUV2 = 1800
PrixUA2 = 1500
promis2 = 15
quantite2 = 15

# %%
# Calcul du chiffre d'affaire (CA)
CA1 = PrixUV1 * quantite1
CA2 = PrixUV2 * quantite2
CA_total = CA1 + CA2

# %%
# Calcul du coût de revient (CR)
CR1 = PrixUA1 * quantite1
CR2 = PrixUA2 * quantite2
CR_total = CR1 + CR2

# %%
# Calcul du bénéfice (CA - CR)
benefice1 = CA1 - CR1
benefice2 = CA2 - CR2
benefice_total = benefice1 + benefice2

# %%
# Affichage des résultats
print("---- Résultats par produit ----")
print("Produit:", produit1)
print("CA =", CA1, "CR =", CR1, "Bénéfice =", benefice1)
print("Produit:", produit2)
print("CA =", CA2, "CR =", CR2, "Bénéfice =", benefice2)

print("\n---- Totaux ----")
print("CA total =", CA_total)
print("CR total =", CR_total)
print("Bénéfice total =", benefice_total)
# Out:
# ---- Résultats par produit ----
# Produit: Iphone
# CA = 25000 CR = 23000 Bénéfice = 2000
# Produit: Samsung
# CA = 27000 CR = 22500 Bénéfice = 4500
#
# ---- Totaux ----
# CA total = 52000
# CR total = 45500
# Bénéfice total = 6500
